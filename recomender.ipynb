# %%
from TalentPeru.Scrapper_jobs.detailed_jobs import JobScrapper
def ejecutar(dep):
    data_dep = JobScrapper(dep=dep).scrapper_sequential()
    return data_dep
lima = '03'
def both_sides(right=True):  # lima
    if right:
        data_dep = JobScrapper(dep=lima).scrapper_both_right()
    else:
        data_dep = JobScrapper(dep=lima).scrapper_both_left()
    return data_dep

# %%
import uuid
uuid.uuid4()
# Out:
# UUID('8fa2680e-bc42-4cca-8fd8-73a6b6423f3f')

# %%
# from openai.embeddings_utils import get_embedding

# %%
data = both_sides()
# Out:
# Departamento de Apurimac - derecha a izquierda: 100%|██████████| 1/1 [00:04<00:00,  4.79s/it]

# %%
data
# Out:
#                               0               ubication
# 0  https://extranet.cunamas.gob  APURIMAC - ANDAHUAYLAS

# %%
import pandas as pd
import tiktoken
import os
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders.csv_loader import CSVLoader

# %%
data
["salary" 
"required_experience"
"educational_background"
"specialization"
"required_knowledge"
"skills"
"job_title"]
# Out:
#                                       job_posting_url vacancies  \
# 0                        https://extranet.cunamas.gob         1
# 1             https://www.reddesaludcotabambas.gob.pe         1
# 2             https://www.reddesaludcotabambas.gob.pe         1
# 3                            https://ugelgrau.gob.pe/         1
# 4                            https://ugelgrau.gob.pe/         1
# 5                https://convocatorias.cofopri.gob.pe         1
# 6                        https://extranet.cunamas.gob         1
# 7                        https://extranet.cunamas.gob         1
# 8   https://http://www.oefa.gob.pe/trabaja-en-el-o...         1
# 9                        https://extranet.cunamas.gob         1
# 10                       https://extranet.cunamas.gob         1
#
#                                    job_posting_number        salary  \
# 0   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 2,614.19
# 1   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 7,300.00
# 2   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 7,300.00
# 3   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 2,814.19
# 4   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 2,614.19
# 5   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 2,200.00
# 6   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 1,614.19
# 7   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 3,014.19
# 8            D.Leg 1057 - Determinado (Suplencia)-138  S/. 2,500.00
# 9   D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 2,914.19
# 10  D.Leg 1057 - Determinado (Necesidad Transitori...  S/. 3,014.19
#
#    start_publication_date end_publication_date  \
# 0              01/10/2024           15/10/2024
# 1              02/10/2024           16/10/2024
# 2              02/10/2024           16/10/2024
# 3              02/10/2024           16/10/2024
# 4              02/10/2024           16/10/2024
# 5              02/10/2024           16/10/2024
# 6              01/10/2024           15/10/2024
# 7              01/10/2024           15/10/2024
# 8              01/10/2024           15/10/2024
# 9              01/10/2024           15/10/2024
# 10             01/10/2024           15/10/2024
#
#                                   required_experience  \
# 0   •\tEXPERIENCIA LABORAL GENERAL DE 01 AÑO.\n•\t...
# 1           DESDE EL AÑO QUE EGRESO COMO ESPECIALISTA
# 2           DESDE EL AÑO QUE EGRESO COMO ESPECIALISTA
# 3            03 AÑOS EN EL SECTOR PÚBLICO Y/O PRIVADO
# 3   ESTUDIOS DE POSGRADO O ESPECIALIZACIÓN O DIPLO...
# 4        INICIATIVA, ANÁLISIS, CONTROL, PLANIFICACIÓN
# 5   •\tINICIATIVA. •\tRESPONSABILIDAD •\tPERSONA P...
# 6   •\tEMPATÍA, COMUNICACIÓN ORAL, INICIATIVA Y PL...
# 7   •\tCOMUNICACIÓN ORAL, EMPATÍA, NEGOCIACIÓN Y P...
# 8   COMPETENCIAS: VOCACIÓN DE SERVICIO, TRABAJO EN...
# 9   •\tCOMUNICACIÓN ORAL, EMPATÍA, NEGOCIACIÓN Y P...
# 10  •\tCOMUNICACIÓN ORAL, EMPATÍA, NEGOCIACIÓN Y P...
#
#                                             job_title  \
# 0   ACOMPAÑANTE TECNICO PARA EL SERVICIO DE CUIDAD...
# 1               MEDICO ESPECIALISTA EN ANESTESIOLOGIA
# 2                    MEDICO ESPECIALISTA EN PEDIATRIA
# 3   PROFESIONAL NO DOCENTE PARA EL SOPORTE Y ASESO...
# 4                                       PSICÓLOGO (A)
# 5                    OPERADOR EN CONDUCCIÓN VEHICULAR
# 6                                 AUXILIAR EN ARCHIVO
# 7   ACOMPAÑANTE TECNICO PARA EL SERVICIO DE ACOMPA...
# 8   AUXILIAR ADMINISTRATIVO - AUXILIAR II (SUPLENC...
# 9   ACOMPAÑANTE TECNICO PARA EL SERVICIO DE CUIDAD...
# 10  ACOMPAÑANTE TECNICO PARA EL SERVICIO DE ACOMPA...
#
#                                    public_institution  \
# 0                          Programa Nacional Cuna Mas
# 1      Unidad Ejecutora De La Red De Salud Cotabambas
# 2      Unidad Ejecutora De La Red De Salud Cotabambas
# 3              Unidad De Gestion Educativa Local Grau
# 4              Unidad De Gestion Educativa Local Grau
# 5   Organismo De Formalizacion De La Propiedad Inf...
# 6                          Programa Nacional Cuna Mas
# 7                          Programa Nacional Cuna Mas
# 8   Organismo De Evaluacion Y Fiscalizacion Ambien...
# 9                          Programa Nacional Cuna Mas
# 10                         Programa Nacional Cuna Mas
#
#                                unique_id                  ubication
# 0   8e27419e-cbab-487f-b845-36fdd76e3810     APURIMAC - ANDAHUAYLAS
# 1   ccd57b75-fc5f-408d-bd31-01724885ce2c      APURIMAC - TAMBOBAMBA
# 2   ee1d5042-0f53-4e71-90de-514b1765c220      APURIMAC - TAMBOBAMBA
# 3   f5be6496-989b-4540-a136-ce200b8ab149  APURIMAC - CHUQUIBAMBILLA
# 4   b94357e5-2f09-4da1-a3d6-3c0fb94a65ec      APURIMAC - VILCABAMBA
# 5   17ce9ab2-7faf-44f5-9f0c-eb3fbf52798f         APURIMAC - ABANCAY
# 6   8dcc430f-5a15-46a7-93a3-bd6048369ad4         APURIMAC - ABANCAY
# 7   7ebc37e8-9c10-403b-8d47-0f67cba29b29      APURIMAC - COTABAMBAS
# 8   7ad3c8c4-5974-47c1-838c-7d85bd1960b3         APURIMAC - ABANCAY
# 9   50e00719-e783-44ab-b1a4-62742d744412     APURIMAC - ANDAHUAYLAS
# 10  320bdff3-8bba-4f93-aa76-409ee8ea8588     APURIMAC - ANDAHUAYLAS

# %%
# data = pd.read_csv("./data/all/12-10-2024.csv")
# data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data = pd.read_csv("./data/all/12-10-2024.csv")
#       2 data
#
# NameError: name 'pd' is not defined
