# %%
from TalentPeru.Scrapper_jobs.with_requests import first_session, left_to_rigth, right_to_left
from rich import print
from bs4 import BeautifulSoup
from TalentPeru.Scrapper_jobs.detailed_jobs import JobScraper

# %%
session, fp_soup, view_value = first_session()
job_n = 0
view = view_value
JobScraper(view, session, 10).get_details_data_in_page()
# Out:
# [{'url_convocatoria': 'página https://www.gob.pe/ugeljunin309 - Facebook y periodico mural en la Sede UGEL Junin',
#   'Cantidad De Vacantes:': '1',
#   'Número De Convocatoria:': '276-002',
#   'Remuneración:': 'S/. 2,321.65',
#   'Fecha Inicio De Publicación:': '08/10/2024',
#   'Fecha Fin De Publicación:': '22/10/2024',
#   'Experiencia:': 'DE ACUERDO AL ANEXO 6C DE LA  RVM 287-2019-MINEDU',
#   'Formación Académica - Perfil:': 'SECUNDARIA COMPLETA',
#   'Especialización:': 'NO APLICA',
#   'Conocimiento:': 'ADMINISTRACIÓN, MANEJO EN OFFICE, MANEJO DE ARCHIVOS, SIAGIE, TRAMITE DOCUMENTARIO, INVENTARIO Y ATENCIÓN AL USUARIO.',
#   'Competencias:': 'ORIENTACIÓN A RESULTADOS, PENSAMIENTOS ANALÍTICO Y ORIENTACIÓN AL SERVICIO, PREDISPOSICION DE ATENCION AL USUARIO, MANEJO DE HABILIADES BLANCAS Y PREDISPOCISION AL TRABAJO EN EQUIPO.',
#   'position': 'OFICINISTA I',
#   'institution': 'Uge Junin',
#   'uuid': 'fd3f212c-ff19-5342-bdcf-7b29c67c07f4'},
# ...

# %%
left_to_rigth(dep='03', view_state_value=view_value, session=session)
JobScraper(view, session, 10).get_details_data_in_page()
# Out:
# 100%|██████████| 3/3 [00:03<00:00,  1.01s/it]
# [{'url_convocatoria': 'www.gob.pe/munichincheros',
#   'Cantidad De Vacantes:': '1',
#   'Número De Convocatoria:': 'D.Leg 1057 - Determinado (Necesidad Transitoria)-03',
#   'Remuneración:': 'S/. 2,300.00',
#   'Fecha Inicio De Publicación:': '25/09/2024',
#   'Fecha Fin De Publicación:': '09/10/2024',
#   'Experiencia:': '•\tEXPERIENCIA GENERAL: DOS (02) AÑOS\n•\tEXPERIENCIA ESPECIFICO (DESARROLLANDO FUNCIONES SIMILARES Y/O EN CARGOS SIMILARES Y/O EN EL SECTOR PÚBLICO):  (01) AÑO EN TEMAS RELACIONADAS A LA GESTIÓN MUNICIPAL, GESTIÓN PÚBLICA Y CONDUCCIÓN DE PERSONAL, DE LOS CUALES (06) MESES DEBE SER EN PUESTO CARGOS DE DIRECCIÓN EN EL SECTOR PÚBLICO O PRIVADO O SU EQUIVALENCIA Y (06) MESES EN EL SECTOR PÚBLICO.',
# ...
